# %% [markdown]
# <a href="https://colab.research.google.com/github/fabiocaso/Learning_Python/blob/master/TestDrive.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # This is my First Test in Python Jupyter LAB

# %% [markdown]
# # Math

# %%
45 + 70
# Out:
# 115

# %%
5 * (12.7 - 4) /2
# Out:
# 21.75

# %%
5 * 12.7 - 4 / 3
# Out:
# 62.166666666666664

# %%
5 * 12.7 - 4 / 6
# Out:
# 62.833333333333336

# %%
45 + 72
# Out:
# 117

# %% [markdown]
# # Strings

# %%
type('word')
# Out:
# str

# %%
type("word")
# Out:
# str

# %%
type(7.5 * 3)
# Out:
# float

# %%
print('int(5.2)', 'trucates 5.2 to', int(5.2))
# Out:
# int(5.2) trucates 5.2 to 5

# %%
name = 'Isabel'
name.startswith('Is')
name.endswith('el')
# Out:
# True

# %% [markdown]
# ✅ Simplest: Put them in one print using \n

# %%
print("#\n#####\n##")
# Out:
# #
# #####
# ##

# %% [markdown]
# ✅ Or use a loop with a list

# %%
for line in ["#", "#####", "##"]:
    print(line)
# Out:
# #
# #####
# ##

# %% [markdown]
# ✅ Or join multiple strings

# %%
print("\n".join(["#", "#####", "##"]))
# Out:
# #
# #####
# ##

# %%
print("Display the name o'Brian")
# Out:
# Display the name o'Brian

# %%
print('Display "HI" in quotes')
# Out:
# Display "HI" in quotes

# %% [markdown]
# # Triple Quoted Strings

# %%
print(""" Display "hi" and 'bye' in quotes""")
# Out:
#  Display "hi" and 'bye' in quotes

# %%
triple_quoted_string = """This is a triple-quoted
string ta spans two lines"""

# %%
triple_quoted_string
# Out:
# 'This is a triple-quoted\nstring ta spans two lines'

# %%
print(triple_quoted_string)
# Out:
# This is a triple-quoted
# string ta spans two lines

# %% [markdown]
# # Input

# %%
name = input("What's you name?")
# Out:
# What's you name?Fabio

# %%
print("Nice to meet you", name)
# Out:
# Nice to meet you Fabio

# %%
v1 = int(input("Enter first number:"))
# Out:
# Enter first number:1

# %%
v2 = int(input("Enter second number:"))
# Out:
# Enter second number:12

# %%
sum = v1 + v2

# %%
print ('The Sum of v1 and v2 is:', sum)
# Out:
# The Sum of v1 and v2 is: 24
