# %% [markdown]
# <a href="https://colab.research.google.com/github/fabiocaso/test/blob/master/TestDrive.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # This is my First Test in Python Jupyter LAB

# %% [markdown]
# # Math

# %%
45 + 70
# Out:
# 115

# %%
5 * (12.7 - 4) /2
# Out:
# 21.75

# %%
5 * 12.7 - 4 / 3
# Out:
# 62.166666666666664

# %%
5 * 12.7 - 4 / 6
# Out:
# 62.833333333333336

# %%
45 + 72
# Out:
# 117

# %% [markdown]
# # Strings

# %%
type('word')
# Out:
# str

# %%
type("word")
# Out:
# str

# %%
print('int(5.2)', 'trucates 5.2 to', int(5.2))
# Out:
# int(5.2) trucates 5.2 to 5
